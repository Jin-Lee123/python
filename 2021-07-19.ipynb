# %%
## 전역 변수 선언 부분 ##
coffee = 0

## 함수 선언 부분 ##
def coffee_machine(button):
    print()
    print("#1. (자동으로) 뜨거운 물을 준비한다.");
    print("#2. (자동으로) 종이컵을 준비한다.");  
    
    if button == 1:
        print("#2. (자동으로) 아메리카노를 탄다.")
    elif button == 2:
        print("#2. (자동으로) 카페라테를 탄다.")
    elif button == 3:
        print("#2. (자동으로) 카푸치노를 탄다.")
    elif button == 4:
        print("#2. (자동으로) 에소프레소를 탄다.")
        
    print("#2. (자동으로) 물을 붓는다."); 
    print("#2. (자동으로) 스푼을 젓는다.");  
    print()
    
## 메인 코드 부분 ##
coffe = int(input("어떤 커피드릴까요?(1:아메리카노, 2:카페라테, 3:카푸치노, 4:에스프레소)"))
cust = input("손님 이름은?")
coffee_machine(coffee)
print("%s님 커피 여기 있습니다." %cust)
# Out:
# 어떤 커피드릴까요?(1:아메리카노, 2:카페라테, 3:카푸치노, 4:에스프레소)2
# 손님 이름은?로제
#
# #1. (자동으로) 뜨거운 물을 준비한다.
# #2. (자동으로) 종이컵을 준비한다.
# #2. (자동으로) 물을 붓는다.
# #2. (자동으로) 스푼을 젓는다.
#
# 로제 커피 여기 있습니다.

# %%
## 함수 선언 부분 ##
def calc(var1, var2, oper):
    
    if oper == '+':
        result = var1 + var2
    elif oper == '-':
        result = var1 - var2
    elif oper == '*':
        result = var1 * var2
    elif oper == '/':
        result = var1 / var2
    return result
        

## 전역 변수 선언 부분 ##
res = 0
var1, var2, oper = 0, 0, ""

## 메인 코드 부분 ##
oper = input("계산을 입력하세요(+,-,*,/) : ")
var1 = int(input("첫 번째 수를 입력하세요 :"))
var2 = int(input("두 번째 수를 입력하세요 :"))

res = calc(var1, var2, oper)
print("##계산기 : %d %s %d = %d " %(var1, oper, var2, res))
# Out:
# 계산을 입력하세요(+,-,*,/) : +
# 첫 번째 수를 입력하세요 :1
# 두 번째 수를 입력하세요 :4
# ##계산기 : 1 + 4 = 5

# %%
## 함수 선언 부분 ##
def calc(var1, var2, oper):
    res = 0
    if oper == '+':
        res = var1 + var2
    elif oper == '-':
        res = var1 - var2
    elif oper == '*':
        res = var1 * var2
    elif oper == '/':
        if var2 == 0:
            print("0으로 나누면 안됩니다 ㅠㅠ")
        else:
            res = var1 / var2
    elif oper == '**':
        res = var1 ** var2
    return res 
        

## 전역 변수 선언 부분 ##
res = 0
var1, var2, oper = 0, 0, ""

## 메인 코드 부분 ##
var1 = int(input("첫 번째 수를 입력하세요 :"))
oper = input("계산을 입력하세요(+,-,*,/,**) : ")
var2 = int(input("두 번째 수를 입력하세요 :"))

res = calc(var1, var2, oper)
print("##계산기 : %d %s %d = %d " %(var1, oper, var2, res))
# Out:
# 첫 번째 수를 입력하세요 :8
# 계산을 입력하세요(+,-,*,/,**) : /
# 두 번째 수를 입력하세요 :2
# ##계산기 : 8 / 2 = 4

# %%
## 함수 선언부분 ##
def multi(v1,v2):
    retList=[]
    res1 = v1 + v2
    res2 = v1 - v2
    res3 = v1 * v2
    retList.append(res1)
    retList.append(res2)
    retList.append(res3)
    return retList

## 전역 변수 선언 부분 ##
myList = []
hap, sub, mul = 0,0,0

## 메인 코드 부분 ##
myList = multi(100,200)
hap = myList[0]
sub = myList[1]
mul  = myList[2]

print("multi()에서 돌려준 값 ==> %d, %d %d " %(hap,sub,mul))
# Out:
# multi()에서 돌려준 값 ==> 300, -100 20000

# %%
import random

#함수선언부분 ##
def getNumber() :
    return random.randrange(1, 46)

#전역 변수 선언##
lotto = []
num = 0

#메인 코드부분
print("로또 추첨을 시작합니다")

while True:
    num=getNumber()
    if num not in lotto:
        lotto.append(num)
        
    if len(lotto) == 6:
        break

print("추첨된 로또 번호 ==>", end = '')
lotto.sort()
for i in range(0, 6) :
    print("%d " %lotto[i], end = '')
# Out:
# 로또 추첨을 시작합니다
# 추첨된 로또 번호 ==>15 22 25 29 34 41

# %%
import random
from tkinter.simpledialog import * 


def getString():
    result = askstring('문자열 입력', '거북이 쓸 문자열을 입력')
    return result

def getRGB():
    r, g, b = random.random(), random.random(), random.random()
    result = (r, g, b)
    return result
    
def getXYAS(swidth, sheight):
    tX = random.randint(-swidth/2, swidth/2)
    tY = random.randint(-swidth/2, swidth/2)
    ang = random.randint(0,360)
    size = random.randint(30,40)
    
    return [tX,tY,ang,size]

# %%
from turtle import *
import turtle

# 전역 변수
inStr = ''
swidth, sheight = 300, 300
tX, tY, tAngle, tSize = [0]*4

# 메인 코드
turtle.title ('거북이 글자 쓰기 (모듈버전)')
turtle.shape('turtle')
turtle.setup(width=swidth+50, height=sheight +50)
turtle.screensize(swidth, sheight)
turtle.penup()
turtle.speed(5)

inStr = getString()

for ch in inStr : 
    tX, tY, tAngle, tSize = getXYAS(swidth, sheight)
    turtle.pencolor(getRGB())
    
    turtle.goto(tX,tY)
    turtle.left(tAngle)
    
    turtle.write(ch,font=('맑은고딕',tSize, 'bold'))
    
turtle.done()

# %%
def Fibonacci(num):
    if num == 0:
        return 0
    elif num == 1 or num == 2:
        return 1
    else:
        return Fibonacci(num-1) + Fibonacci(num-2)
print(Fibonacci(0))
print(Fibonacci(1))
print(Fibonacci(2))
print(Fibonacci(3))
print(Fibonacci(4))
print(Fibonacci(5))
print(Fibonacci(6))
print(Fibonacci(7))
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
import  os

print("현재 운영체제 : ", os.name)
print("현대 폴더 : ", os.getcwd())
print("현재 폴대 내부의 요소 : ", os.listdir())

os.mkdir("hello")
os.rmdir("hello")

with open ("original.txt", "w" ) as file:
    file.write("hello")
os.rename("original.txt", "new.txt")

os.remove("new.txt")

os.system("dir")
# Out:
# 현재 운영체제 :  nt
# 현대 폴더 :  C:\Users\admin
# ...

# %%
from urllib import request

target = request.urlopen("http://google.com")
output = target.read()

print(output)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="Wn4m8YajszWtrshV+fnV/A==">(function(){window.google={kEI:\'2BX1YKu_E4TVmAXSrpPIAg\',kEXPI:\'0,772215,1,530320,56873,954,5105,206,2414,2390,2316,383,246,5,1354,5251,1122515,1197708,574,328985,51224,16111,19400,9287,17572,4858,998,364,9291,3023,2820,1931,12834,4020,978,13228,3847,4192,6430,7432,7095,236,4282,2777,919,6674,1279,2212,241,289,149,1103,840,2197,4100,109,3405,606,2023,2297,14670,3227,2845,7,12354,5096,7876,5037,3407,908,2,3555,13142,3,576,4386,2074,148,12314,1661,4,1528,2304,1236,5803,4684,203,1811,4067,9544,4764,2658,6701,656,30,3878,9750,1590,715,638,1494,5586,3772,6763,665,5806,2551,4094,19,2238,881,6,613,295,3,3541,1,14710,1814,283,912,5992,10619,1907,2,1394,2806,1715,2,3035,22,2538,2,1,3,
# ...

# %%
pip install beautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib import request
from bs4 import BeautifulSoup

# urlopen() 함수로 기상청의 전국 날씨를 읽습니다.
target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

# BeautifulSoup을 사용해 웹 페이지를 분석합니다.
soup = BeautifulSoup(target, "html.parser")

# location 태그를 찾습니다.
for location in soup.select("location"):
    # 내부의 city, wf, tmn, tms 태그를 찾아 출력합니다.
    print("도시:", location.select_one("city").string)
    print("날씨:", location.select_one("wf").string)
    print("최저기온:", location.select_one("tmn").string)
    print("최고기온:", location.select_one("tmx").string)
    print()
# Out:
# 도시: 서울
# 날씨: 구름많음
# 최저기온: 26
# 최고기온: 36
#
# 도시: 인천
# 날씨: 구름많음
# 최저기온: 25
# 최고기온: 34
#
# 도시: 수원
# 날씨: 구름많음
# 최저기온: 25
# 최고기온: 36
#
# 도시: 파주
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 34
#
# 도시: 이천
# 날씨: 구름많음
# 최저기온: 22
# 최고기온: 34
#
# 도시: 평택
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 34
#
# 도시: 춘천
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 35
#
# 도시: 원주
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 34
#
# 도시: 강릉
# 날씨: 구름많음
# 최저기온: 24
# 최고기온: 33
#
# 도시: 대전
# 날씨: 구름많음
# 최저기온: 25
# 최고기온: 35
#
# 도시: 세종
# 날씨: 구름많음
# 최저기온: 24
# 최고기온: 35
#
# 도시: 홍성
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 34
#
# 도시: 청주
# 날씨: 구름많음
# 최저기온: 24
# 최고기온: 34
#
# 도시: 충주
# 날씨: 구름많음
# 최저기온: 22
# 최고기온: 34
#
# 도시: 영동
# 날씨: 구름많음
# 최저기온: 21
# 최고기온: 34
#
# 도시: 광주
# 날씨: 구름많음
# 최저기온: 24
# 최고기온: 34
#
# 도시: 목포
# 날씨: 구름많음
# 최저기온: 25
# 최고기온: 32
#
# 도시: 여수
# 날씨: 구름많음
# 최저기온: 25
# 최고기온: 31
#
# 도시: 순천
# 날씨: 구름많음
# 최저기온: 24
# 최고기온: 33
#
# 도시: 광양
# 날씨: 구름많음
# 최저기온: 24
# 최고기온: 32
#
# 도시: 나주
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 34
#
# 도시: 전주
# 날씨: 구름많음
# 최저기온: 23
# 최고기온: 35
#
# 도시: 군산
# 날씨: 구름많음
# 최저기온: 24
# ...

# %%
# 모듈을 읽어 들입니다.
from flask import Flask
from urllib import request
from bs4 import BeautifulSoup

# 웹 서버를 생성합니다.
app = Flask(__name__)
@app.route("/")

def hello():
    # urlopen() 함수로 기상청의 전국 날씨를 읽습니다.
    target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

    # BeautifulSoup를 사용해 웹 페이지를 분석합니다.
    soup = BeautifulSoup(target, "html.parser")

    # location 태그를 찾습니다.
    output = ""
    for location in soup.select("location"):
        # 내부의 city, wf, tmn, tmx 태그를 찾아 출력합니다.
        output += "<h3>{}</h3>".format(location.select_one("city").string)
        output += "날씨: {}<br/>".format(location.select_one("wf").string)
        output += "최저/최고 기온: {}/{}"\
            .format(\
                location.select_one("tmn").string,\
                location.select_one("tmx").string\
            )
        output += "<hr/>"
    return output

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello():
    return "<h1>Hello World!</h1>"

# %%
# main.py 파일
import test_module as test

radius = test.number_input()
print(test.get_circumference(radius))
print(test.get_circle_area(radius))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-a7e792d0236b> in <module>
#       1 # main.py 파일
# ----> 2 import test_module as test
#       3
#       4 radius = test.number_input()
#       5 print(test.get_circumference(radius))
#
# ModuleNotFoundError: No module named 'test_module'

# %%
inFp = None
inStr = ""

inFp = open("C:\Users\admin\Desktop\test\data2.txt", "r")

inStr = inFp.redaline()
print(inStr,end="")

inStr = inFp.redaline()
print(inStr,end="")

inStr = inFp.redaline()
print(inStr,end="")

inFp.close()
# Out:
#   File "<ipython-input-55-19977ce50c85>", line 4
#     inFp = open("C:\Users\admin\Desktop\test\data2.txt", "r")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
